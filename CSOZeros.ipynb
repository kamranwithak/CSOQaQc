# %% [markdown]
# # CSO QaQc: Zero Depth Value Exploration
#
# We know that `Zero` depth values are worth keeping and valuable pieces of data. However there seems to be some inconsistencies when it comes to the filtering of these values, we will explore this in this Notebook

# %%
import requests
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.io.img_tiles as cimgt

# Import necessary packages, may need more or less as I go.

# %%
CSO_gdf = gpd.read_file('CSOgeodata.geojson')
CSO_gdf['timestamp'] = pd.to_datetime(CSO_gdf.timestamp)

# %%
CSO_gdf['flags'] = False
CSO_gdf
# Out:
#              id               author  depth       source  \
# 0      4J5z5w7h       camila chamizo  150.0    SnowPilot
# 1      2C8R7ehK       camila chamizo  150.0    SnowPilot
# 2      a3a3VCXY  juan manuel raselli  155.0    SnowPilot
# 3      ImH60r2U          John Soltys   90.0  MountainHub
# 4      mebZPRGY   Roberto indio Treu  400.0    SnowPilot
# ...         ...                  ...    ...          ...
# 30492  H2E/jXmC             aask@nve   18.0       regObs
# 30493  caoWAbeB             aask@nve   49.0       regObs
# 30494  f63KW/A1             aask@nve   32.0       regObs
# 30495  m+lrqT6a             aask@nve    9.0       regObs
# 30496  m+8tg6Vk             aask@nve   10.0       regObs
#
#                              timestamp    elevation  \
# 0            2021-06-28 20:15:00+00:00  1881.618530
# 1            2021-06-28 18:15:00+00:00  1881.618530
# 2            2021-06-26 20:00:00+00:00  1577.167603
# 3     2021-06-26 15:12:30.931999+00:00  1585.094727
# 4            2021-06-25 15:00:00+00:00  1568.316284
# ...                                ...          ...
# 30492        1975-03-04 16:30:00+00:00   851.000000
# 30493        1974-03-08 15:50:00+00:00   984.000000
# 30494        1974-03-08 12:20:00+00:00   851.000000
# 30495        1974-03-08 10:40:00+00:00   362.000000
# 30496        1969-02-24 12:00:00+00:00   251.000000
#
#                           geometry  flags
# 0      POINT (-71.56655 -41.10209)  False
# 1      POINT (-71.56655 -41.10209)  False
# 2      POINT (-72.93703 -49.07451)  False
# 3      POINT (-121.40983 47.45218)  False
# 4      POINT (-72.93789 -49.07159)  False
# ...                            ...    ...
# 30492     POINT (8.94487 61.78813)  False
# 30493     POINT (8.74345 61.49456)  False
# 30494     POINT (8.94487 61.78813)  False
# 30495     POINT (8.94222 61.85313)  False
# 30496    POINT (11.21452 61.57384)  False
#
# [30497 rows x 8 columns]

# %%
ZERO = 0
CSO_gdf.loc[CSO_gdf['depth'] <= ZERO, 'flags'] = True
CSO_noZeros = (CSO_gdf.loc[CSO_gdf['flags'] == False])
CSO_zeros = CSO_gdf.loc[CSO_gdf['flags'] == True]
CSO_zeros
# Out:
#              id               author  depth       source  \
# 17455  j/m7oRHe           Bart Wills    0.0  MountainHub
# 17518  xStFQaxG        Ben Pritchett    0.0    SnowPilot
# 17539  mqTo9/Wd    Chris McCollister    0.0    SnowPilot
# 17573  iDn+SCXH          Finn Wright    0.0    SnowPilot
# 17605  +8gZ8XUU  Remarks Snow Safety    0.0    SnowPilot
# ...         ...                  ...    ...          ...
# 24359  1RVdBDqO          David Brown    0.0    SnowPilot
# 24387  bV2w6An3          Kory Davis     0.0    SnowPilot
# 24388  EYVAHfT8      Burket Kniveton    0.0    SnowPilot
# 24392  L59wWjgw         Mark Staples    0.0    SnowPilot
# 24467  fuUdlYLv          Troy Marino    0.0    SnowPilot
#
#                              timestamp    elevation  \
# 17455 2018-11-17 22:03:47.806000+00:00  1998.644653
# 17518        2018-11-07 23:00:00+00:00  3677.466797
# 17539        2018-11-01 19:15:00+00:00  2793.014893
# 17573        2018-10-04 18:00:00+00:00  1692.729980
# 17605        2018-08-27 18:30:00+00:00  1918.912598
# ...                                ...          ...
# 24359        2016-12-11 22:42:44+00:00  2844.528320
# 24387        2016-12-10 02:32:12+00:00  2207.748535
# 24388        2016-12-10 01:33:22+00:00  1853.509766
# 24392        2016-12-09 23:20:32+00:00  2666.063965
# 24467        2016-12-04 17:58:54+00:00  3275.851562
#
#                           geometry  flags
# 17455  POINT (-121.73205 44.08389)   True
# 17518  POINT (-106.56653 39.07887)   True
# 17539  POINT (-110.95248 43.47822)   True
# 17573  POINT (175.53269 -39.30351)   True
# 17605  POINT (168.82539 -45.05029)   True
# ...                            ...    ...
# 24359  POINT (-111.44531 45.27574)   True
# 24387  POINT (-111.94193 41.37743)   True
# 24388  POINT (-113.67233 48.27228)   True
# 24392  POINT (-111.67196 40.66272)   True
# 24467  POINT (-111.65869 35.32772)   True
#
# [184 rows x 8 columns]

# %%
CSO_zeros[['depth','source']].groupby(['source']).agg(['count'])
# Out:
#             depth
#             count
# source
# MountainHub    24
# SnowPilot     160

# %% [markdown]
# ### SnowPilot Zeros
#
# * These have been discussed to be mostly unintentional due to some problem when compiling the data from SnowPilot as it has many more fields to fill in when compared to thing such as MountainHub. We need to reach out and figure out the procedure/see if these are intentional.
#
# ### MountainHub Zeros
#
# * These are valuable pieces of data however there is only 24 pieces of data, which seems rather low when considering the amount of `Zeros` that people have said they have submitted.

# %%
CSO_zeros.loc[CSO_zeros['source'] == "MountainHub"]
# Out:
#              id                        author  depth       source  \
# 17455  j/m7oRHe                    Bart Wills    0.0  MountainHub
# 17736  jcnILKo9                   Emily Baker    0.0  MountainHub
# 17772  FOBtszAf                     Mara Gans    0.0  MountainHub
# 17846  W77sQPH6                    Snow Bloom    0.0  MountainHub
# 19683  rMtxihZp  BSA troop 115 Snoqualmie, WA    0.0  MountainHub
# 19814  WizcsgaN  BSA troop 115 Snoqualmie, WA    0.0  MountainHub
# 20556  xt6cnm1X                  Aaron Miller    0.0  MountainHub
# 20759  VdZRlPAP                  Karri Sicard    0.0  MountainHub
# 20936  bs4/zBDi                   Shaun Wicen    0.0  MountainHub
# 21133  mUBi94GT                      Geo Jord    0.0  MountainHub
# 21158  p6OPKXit                 Joseph Kurtak    0.0  MountainHub
# 21334  VzBBu+rM                  Muff Winwood    0.0  MountainHub
# 21825  9Ztc55F+                   Emily Baker    0.0  MountainHub
# 21840  K1MqIvu5                         Ville    0.0  MountainHub
# 21849  ZRF0IRMB                     Brandon A    0.0  MountainHub
# 22223  MhiNyK3w                   Bobby Liebs    0.0  MountainHub
# 22225  b2ZP8O8c                   Bobby Liebs    0.0  MountainHub
# 22238  gE/0gXf3                Gabriel Wolken    0.0  MountainHub
# 22654  OpdlXY8L        Katreen Wikstrom Jones    0.0  MountainHub
# 22672  LuQBD52i        Katreen Wikstrom Jones    0.0  MountainHub
# 22722  PGve5nES        Katreen Wikstrom Jones    0.0  MountainHub
# 22723  YubxeKH0        Katreen Wikstrom Jones    0.0  MountainHub
# ...         ...         ...     ...          ...
# 21542  7BB+SBZV  David Hill   35.56  MountainHub
# 21697  H1fgS9Sa  David Hill   55.88  MountainHub
# 21766  2GZ+o/nC  David Hill   46.00  MountainHub
# 21832  X9x9gJfK  David Hill    2.54  MountainHub
# 21844  whHzE7cf  David Hill   43.18  MountainHub
#
#                              timestamp    elevation  \
# 109   2021-05-11 18:44:14.283000+00:00  2577.653564
# 1611  2021-03-13 16:16:21.386000+00:00  2108.131836
# 1612  2021-03-13 15:24:32.368999+00:00  1977.794678
# 2251  2021-02-28 22:37:50.908001+00:00  2292.394287
# 2310  2021-02-27 22:52:40.257999+00:00  2146.215088
# ...                                ...          ...
# 21542        2017-11-22 20:00:00+00:00  1530.093140
# 21697        2017-11-15 20:00:00+00:00  1530.046509
# 21766        2017-11-08 20:00:00+00:00  1530.113159
# 21832        2017-10-22 19:00:00+00:00  1530.700195
# 21844        2017-10-15 19:00:00+00:00  1530.480347
#
#                           geometry  flags
# 109    POINT (-122.14950 43.52067)  False
# 1611   POINT (-122.08692 43.14962)  False
# 1612   POINT (-122.10008 43.14938)  False
# 2251   POINT (-122.23240 41.36627)  False
# 2310   POINT (-122.23967 41.35884)  False
# ...                            ...    ...
# 21542  POINT (-121.88220 44.40199)  False
# 21697  POINT (-121.88218 44.40199)  False
# 21766  POINT (-121.88215 44.40202)  False
# 21832  POINT (-121.88225 44.40207)  False
# 21844  POINT (-121.88228 44.40200)  False
#
# [147 rows x 8 columns]

# %%
CSO_DAVE_zeros = CSO_DAVE.loc[CSO_DAVE['flags'] == True]
CSO_DAVE_zeros
# Out:
# Empty GeoDataFrame
# Columns: [id, author, depth, source, timestamp, elevation, geometry, flags]
# Index: []

# %% [markdown]
# We can see that theres still no `Zero` depth values for Dave even though he had said that he had recorded them. This will take some asking around as I could be wrong in this assumption.

# %% [markdown]
# ### Histogram for Elevation of CSO dataset

# %%
histogram_gdf = CSO_gdf['elevation'].hist(bins = 25)

# %% [markdown]
# ### Histogram for Elevation of CSO zero values

# %%
histogram_flag = CSO_zeros['elevation'].hist(bins = 25)

# %% [markdown]
# ### Histogram for CSO data depth values

# %%
histogram_depth = CSO_gdf['depth'].hist(bins = 25)

# %% [markdown]
# Looking at the Depth values on the histogram we can see that most depth observations are under 200 cm. With this in mind we can possible remove bad depth observations by flagging values that are unreasonably low.

# %% [markdown]
# ## Flagging values for depth observations that are unreasonably low.
#
# This is a somewhat arbitrary test and may need some fleshing out in terms of numbers.

# %%
LOW = 3
CSO_gdf_LOW = gpd.read_file('CSOgeodata.txt')
CSO_gdf_LOW.loc[CSO_gdf_LOW['depth'] <= LOW, 'flags'] = True
CSO_gdf_LOW.loc[CSO_gdf_LOW['depth'] == ZERO, 'flags'] = False
CSO_LOW = CSO_gdf_LOW.loc[CSO_gdf_LOW['flags'] == True]
CSO_LOW
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: CSOgeodata.txt: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-12-26f4b52df4bc> in <module>
#       1 LOW = 3
# ----> 2 CSO_gdf_LOW = gpd.read_file('CSOgeodata.txt')
#       3 CSO_gdf_LOW.loc[CSO_gdf_LOW['depth'] <= LOW, 'flags'] = True
#       4 CSO_gdf_LOW.loc[CSO_gdf_LOW['depth'] == ZERO, 'flags'] = False
#       5 CSO_LOW = CSO_gdf_LOW.loc[CSO_gdf_LOW['flags'] == True]
#
# ~/opt/miniconda3/envs/cso_obsdata/lib/python3.9/site-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#     158
#     159     with fiona_env():
# --> 160         with reader(path_or_bytes, **kwargs) as features:
#     161
#     162             # In a future Fiona release the crs attribute of features will
#
# ~/opt/miniconda3/envs/cso_obsdata/lib/python3.9/site-packages/fiona/env.py in wrapper(*args, **kwargs)
#     398     def wrapper(*args, **kwargs):
#     399         if local._env:
# --> 400             return f(*args, **kwargs)
#     401         else:
#     402             if isinstance(args[0], str):
#
# ~/opt/miniconda3/envs/cso_obsdata/lib/python3.9/site-packages/fiona/__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     254
#     255         if mode in ('a', 'r'):
# --> 256             c = Collection(path, mode, driver=driver, encoding=encoding,
#     257                            layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     258         elif mode == 'w':
#
# ~/opt/miniconda3/envs/cso_obsdata/lib/python3.9/site-packages/fiona/collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     160             if self.mode == 'r':
#     161                 self.session = Session()
# --> 162                 self.session.start(self, **kwargs)
#     163             elif self.mode in ('a', 'w'):
#     164                 self.session = WritingSession()
#
# fiona/ogrext.pyx in fiona.ogrext.Session.start()
#
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# DriverError: CSOgeodata.txt: No such file or directory

# %%
CSO_LOW[['depth','source']].groupby(['source']).agg(['count'])

# %%
CSO_LOW.loc[CSO_LOW['source'] == "MountainHub"]

# %% [markdown]
# I think using an unreasonably low check seems to be a bit unecessary as it seems that many of our own team members are recording low depth values, so the authenticity of low values seems fairly strong.

# %% [markdown]
# ## How Impactful Are Zero Values?
#
# Here is where I'll explore how much impact `Zero` depth values have on things such as discriptive statistics.

# %%
# Here is the mean depth value of the CSO data.
CSO_mean = CSO_gdf['depth'].mean()
CSO_mean

# %%
# Here is the mean now with zero values excluded from the data.
CSO_meanNoZero = CSO_noZeros['depth'].mean()
CSO_meanNoZero

# %% [markdown]
# Interestingly, they don't actually have that much of an effect on the data set when looked as a WHOLE. This makes sense as they make up a small amount of the data.

# %% [markdown]
# ## Domain Specific Zero Depth Exploration
#
# Now we will be looking at a region where `Zero` depth values actually have a noticeable impact on the data. This region will be California as defined by `CSO_CA`.

# %%
CSO_CA = gpd.read_file('CSO_CA')
CSO_gdf['timestamp'] = pd.to_datetime(CSO_gdf.timestamp)

# %%
CSO_CA['flags'] = False
CSO_CA

# %%
CSO_CA.loc[CSO_CA['depth'] <= ZERO, 'flags'] = True
CSO_noCA = (CSO_CA.loc[CSO_CA['flags'] == False])
CSO_CAzeros = CSO_CA.loc[CSO_CA['flags'] == True]
CSO_CAzeros

# %%
CSO_CAzeros[['depth','source']].groupby(['source']).agg(['count'])

# %%
CSO_meanCA = CSO_CA['depth'].mean()
CSO_meanCA

# %%
CSO_noZeroMean = CSO_noCA['depth'].mean()
CSO_noZeroMean

# %%
histogram_CA = CSO_CA['elevation'].hist(bins = 50)
histogram_CA

# %%
histogram_CAnoZeros = CSO_noCA['elevation'].hist(bins = 50)
histogram_CAnoZeros

# %% [markdown]
# The zeros are actually very impactful in this region as the amount of `Zero` depth values is relatively higher than most regions.

# %% [markdown]
# From all of this exploration I think it highlights an important aspect that I have not mentioned. The effect that `Zero` depth values have is very reliant on the amount of data in a given region. If we look at California as defined by `CSO_CA` we can see that Zeros are actually very impactful as that region has a rather large amount of these values when compared to most. These also all seem a bit unintentional as they come from SnowPilot. Also another interesting fact about those SnowPilot `Zero` depth values is that they ALL come from 2017. So I wonder if there was some sort of miscommunication or a specific part of 2017 that lead to this possible error.
